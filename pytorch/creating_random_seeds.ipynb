# %%
import numpy as np
import pandas as pd 

root_seed = 100

np.random.seed(root_seed)

seeds = np.random.randint(0,256,size=(10,4))

seed_table = pd.DataFrame(seeds,columns=['Dataset Split','Dataset Transform','Dataset Shuffle','Model Weights'])
seed_table.index = list(range(1,11))
seed_table.index.name = 'TrialNumber'
seed_table
# Out:
#              Dataset Split  Dataset Transform  Dataset Shuffle  Model Weights
# TrialNumber
# 1                        8                 24               67            103
# 2                       87                 79              176            138
# 3                       94                180               98             53
# 4                       66                226               14             34
# 5                      241                240               24            143
# 6                      228                107               60             58
# 7                      144                251              137             93
# 8                       86                130              155            108
# 9                      132                159              129            141
# 10                     245                211              100              4
